# %% [markdown]
# <a href="https://colab.research.google.com/github/slikitha2503-arch/ict-academy/blob/main/k_mean_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#k-mean clustering example: group customer
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#sample data
df=pd.read_excel('/content/sample_data/Mall_Customers.xlsx')
print(df.head())
# Out:
#    CustomerID   Genre  Age  Annual Income  Spending Score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %%
#create k-mean model
kmeans=KMeans(n_clusters=3, random_state=42)
df['cluster']=kmeans.fit_predict(df[['Annual Income', 'Spending Score']])

# %%
#centroids
centroids=kmeans.cluster_centers_

# %%
#plot clusters
plt.scatter(df['Annual Income'], df['Spending Score'], c=df['cluster'],cmap='rainbow')
plt.scatter(centroids[:,0], centroids[:,1], color='black', marker='x',s=100)
plt.xlabel('Annual Income')
plt.ylabel('spending score')
plt.title('k-mean clusterng example')
plt.show()

# %% [markdown]
# sample 2

# %%
#sample data 2
df=pd.read_csv('/content/sample_data/home-rental.csv')
print(df.head())
# Out:
#    property_id            address  postal_code  size  bedrooms  rent_amount
# 0            1     123 Oak Street        12345  1200         2         1680
# 1            2    456 Pine Avenue        23456  1800         3         2590
# 2            3    789 Maple Drive        34567   950         1         1520
# 3            4  321 Elm Boulevard        45678  2200         4         3240
# 4            5     654 Cedar Lane        56789  1450         2         2030

# %%
#create k-mean model
kmeans=KMeans(n_clusters=3, random_state=42)
df['cluster']=kmeans.fit_predict(df[['postal_code', 'rent_amount']])

# %%
#centroids
centroids=kmeans.cluster_centers_

# %%
#plot clusters
plt.scatter(df['postal_code'], df['rent_amount'], c=df['cluster'],cmap='rainbow')
plt.scatter(centroids[:,0], centroids[:,1], color='black', marker='x',s=100)
plt.xlabel('postal_code')
plt.ylabel('rent_amount')
plt.title('k-mean clusterng example')
plt.show()
